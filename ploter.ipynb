# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show, save, output_file
from bokeh.embed import file_html
from bokeh.models import LinearColorMapper, Range1d

# %% [markdown]
# opening the file

# %%
# The RIGHT way:        
colnames=['position', 'energy'] 
atoms = pd.read_csv(r"C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\200_data_far\At18-200.0.csv" , sep = ",", names=colnames)

# %% [markdown]
# Printing the read data please comment it

# %% [markdown]
# Define the figure

# %%
#370 390 410 430 450 470 490 500
fig = plt.figure()
plt.xlim([-10,10])
#plt.ylabel('Kinetic Energy')
plt.ylabel('$E/E_{max}$')
#plt.xlabel('Y (Sliced Dimension)')
plt.xlabel('X (Sliced Dimension)')

fig= plt.scatter(atoms.position, atoms.energy, s=2,label="at z=")
plt.savefig('At19-200.0.far.png')
#plt.show()

# %% [markdown]
# Find the max

# %%
# output to static HTML file
output_file(filename="At19-200.0.far.html", title="Static HTML file")
TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,examine,help"
p = figure(tools=TOOLS)
p.x_range = Range1d(-20, 20)
p.scatter (atoms.position,atoms.energy, color="red", alpha=0.5)
# show the results
#show(p)
save(p)
# Out:
# 'c:\\Users\\nikidis\\Documents\\GitHub\\phonons\\At19-200.0.far.html'
