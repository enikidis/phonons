# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show, save, output_file
from bokeh.embed import file_html
from bokeh.models import LinearColorMapper, Range1d

# %% [markdown]
# opening the file

# %%
d=40
for step in range(7, 16):
    print("Reading data files")
    filename= fr"C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\{d}_data\At{step}-{d}.0.csv"
    print(filename)
    # The RIGHT way:        
    colnames=['position', 'energy'] 
    atoms = pd.read_csv(fr"{filename}" , sep = ",", names=colnames)
    #370 390 410 430 450 470 490 500
    fig = plt.figure()
    plt.xlim([-10,10])
    #plt.ylabel('Kinetic Energy')
    plt.ylabel('$E/E_{max}$')
    #plt.xlabel('Y (Sliced Dimension)')
    plt.xlabel('X (Sliced Dimension)')

    fig= plt.scatter(atoms.position, atoms.energy, s=2,label="at z=")
    plt.savefig(f'At{step}-{d}.0.png')
    #plt.show()
    # output to static HTML file
    output_file(filename=f"At{step}-{d}.0.html", title="Static HTML file")
    TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,examine,help"
    p = figure(tools=TOOLS)
    p.x_range = Range1d(-20, 20)
    p.scatter (atoms.position,atoms.energy, color="red", alpha=0.5)
    # show the results
    #show(p)
    save(p)
# Out:
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At7-40.0.csv
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At8-40.0.csv
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At9-40.0.csv
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At10-40.0.csv
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At11-40.0.csv
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At12-40.0.csv
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At13-40.0.csv
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At14-40.0.csv
# Reading data files
# C:\Users\nikidis\Documents\GitHub\phonons\paul_sim_output\data\40_data\At15-40.0.csv
