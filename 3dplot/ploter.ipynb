# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show, save, output_file
from bokeh.embed import file_html
from bokeh.models import LinearColorMapper

# %% [markdown]
# opening the file

# %%
# The RIGHT way:        
colnames=['position', 'energy'] 
atoms = pd.read_csv("14_370.csv", sep = ",", names=colnames)

# %% [markdown]
# Printing the read data please comment it

# %% [markdown]
# Define the figure

# %%
fig = plt.figure()
plt.ylabel('Kinetic Energy')
plt.xlabel('Y (Sliced Dimension)')
fig= plt.scatter(atoms.position, atoms.energy, s=2)
plt.savefig('25.png')
plt.show()

# %% [markdown]
# Find the max

# %%
#atoms['energy'].nlargest(10)

# %%
# output to static HTML file
output_file(filename="55.html", title="Static HTML file")
TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,examine,help"
p = figure(tools=TOOLS)
p.scatter (atoms.position,atoms.energy, color="red", alpha=0.5)


# show the results
show(p)

save(p)
# Out:
# '/Users/nikidis/Documents/GitHub/phonons/3dplot/55.html'

# %%
atoms.energy.min()
# Out:
# 9.945128e-13
