# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import LinearColorMapper

# %% [markdown]
# opening the file

# %%
# fo'kin lists
# readfile = open("test_Data.csv", "r")
# x=[]
# y=[]
# for line in readfile:
#         Type = line.split( )
#         # atoms.append((float(Type[0]),float(Type[1])))
#         x.append(float(Type[0]))
#         y.append(float(Type[1]))

# The RIGHT way:        
colnames=['position', 'energy'] 
atoms = pd.read_csv("test_Data.csv", sep = ";", names=colnames)

# %% [markdown]
# Printing the read data please comment it

# %% [markdown]
# Define the figure

# %%
fig = plt.figure()
fig= plt.scatter(atoms.position, atoms.energy, s=2)

plt.show()

# %% [markdown]
# Find the max

# %%
#atoms['energy'].nlargest(10)

# %%
# output to static HTML file
output_file=("line.html")
TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,examine,help"
p = figure(tools=TOOLS)

#color_mapper = LinearColorMapper(palette='Magma256', low=atoms.energy.min(), high=atoms.energy.max())
p.scatter (atoms.position,atoms.energy, color="red", alpha=0.5)
# add a circle renderer with a size, color, and alpha
#p.circle(atoms.position,atoms.energy, color="navy", alpha=0.5)

# show the results
show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 7
#       4 p = figure(tools=TOOLS)
#       6 color_mapper = LinearColorMapper(palette='Magma256', low=atoms.energy.min(), high=atoms.energy.max())
# ----> 7 p.scatter (atoms.position,atoms.energy, color=color_mapper, alpha=0.5)
#       8 # add a circle renderer with a size, color, and alpha
#       9 #p.circle(atoms.position,atoms.energy, color="navy", alpha=0.5)
#      10
#      11 # show the results
#      12 show(p)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/plotting/glyph_api.py:966, in GlyphAPI.scatter(self, *args, **kwargs)
#     964     return self.circle(*args, **kwargs)
#     965 else:
# --> 966     return self._scatter(*args, marker=marker_type, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/plotting/_decorators.py:87, in glyph_method.<locals>.decorator.<locals>.wrapped(self, *args, **kwargs)
#      85 if self.coordinates is not None:
#      86     kwargs.setdefault("coordinates", self.coordinates)
# ---> 87 return create_renderer(glyphclass, self.plot, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/plotting/_renderer.py:113, in create_renderer(glyphclass, plot, **kwargs)
#     110 # handle the mute glyph, we always set one
#     111 muted_visuals = pop_visuals(glyphclass, kwargs, prefix='muted_', defaults=glyph_visuals, override_defaults={'alpha':0.2})
# --> 113 glyph = make_glyph(glyphclass, kwargs, glyph_visuals)
#     114 nonselection_glyph = make_glyph(glyphclass, kwargs, nonselection_visuals)
#     115 selection_glyph = make_glyph(glyphclass, kwargs, selection_visuals)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/plotting/_renderer.py:142, in make_glyph(glyphclass, kws, extra)
#     140 kws = kws.copy()
#     141 kws.update(extra)
# --> 142 return glyphclass(**kws)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/models/glyphs.py:1278, in Scatter.__init__(self, *args, **kwargs)
#    1277 def __init__(self, *args, **kwargs) -> None:
# -> 1278     super().__init__(*args, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/models/glyphs.py:156, in Marker.__init__(self, *args, **kwargs)
#     155 def __init__(self, *args, **kwargs) -> None:
# --> 156     super().__init__(*args, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/models/glyph.py:80, in XYGlyph.__init__(self, *args, **kwargs)
#      79 def __init__(self, *args, **kwargs) -> None:
# ---> 80     super().__init__(*args, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/models/glyph.py:101, in LineGlyph.__init__(self, *args, **kwargs)
#     100 def __init__(self, *args, **kwargs) -> None:
# --> 101     super().__init__(*args, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/models/glyph.py:111, in FillGlyph.__init__(self, *args, **kwargs)
#     110 def __init__(self, *args, **kwargs) -> None:
# --> 111     super().__init__(*args, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/models/glyph.py:131, in HatchGlyph.__init__(self, *args, **kwargs)
#     130 def __init__(self, *args, **kwargs) -> None:
# --> 131     super().__init__(*args, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/models/glyph.py:58, in Glyph.__init__(self, *args, **kwargs)
#      57 def __init__(self, *args, **kwargs) -> None:
# ---> 58     super().__init__(*args, **kwargs)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/model/model.py:115, in Model.__init__(self, *args, **kwargs)
#     112 if "id" in kwargs:
#     113     raise ValueError("initializing 'id' is not allowed")
# --> 115 super().__init__(**kwargs)
#     116 default_theme.apply_to_model(self)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/core/has_props.py:298, in HasProps.__init__(self, **properties)
#     296     if value is Undefined or value is Intrinsic:
#     297         continue
# --> 298     setattr(self, name, value)
#     300 for name in self.properties() - set(properties.keys()):
#     301     desc = self.lookup(name)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/core/has_props.py:327, in HasProps.__setattr__(self, name, value)
#     325 properties = self.properties(_with_props=True)
#     326 if name in properties:
# --> 327     return super().__setattr__(name, value)
#     329 descriptor = getattr(self.__class__, name, None)
#     330 if isinstance(descriptor, property): # Python property
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/core/property/descriptors.py:289, in PropertyDescriptor.__set__(self, obj, value, setter)
#     286     class_name = obj.__class__.__name__
#     287     raise RuntimeError(f"{class_name}.{self.name} is a readonly property")
# --> 289 value = self.property.prepare_value(obj, self.name, value)
#     290 old = self._get(obj)
#     291 self._set(obj, old, value, setter=setter)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/core/property/dataspec.py:615, in ColorSpec.prepare_value(self, cls, name, value)
#     613 if self.is_color_tuple_shape(value):
#     614     value = tuple(int(v) if i < 3 else v for i, v in enumerate(value))
# --> 615 return super().prepare_value(cls, name, value)
#
# File ~/Documents/Silicon archive/3dplot/.venv/lib/python3.10/site-packages/bokeh/core/property/bases.py:365, in Property.prepare_value(self, owner, name, value, hint)
#     363 else:
#     364     obj_repr = owner if isinstance(owner, HasProps) else owner.__name__
# --> 365     raise ValueError(f"failed to validate {obj_repr}.{name}: {error}")
#     367 if isinstance(owner, HasProps):
#     368     obj = owner
#
# ValueError: failed to validate Scatter(id='p1079', ...).line_color: expected an element of either String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)) or Struct(expr=Instance(Expression), transform=Instance(Transform)), got LinearColorMapper(id='p1075', ...)

# %%
atoms.energy.min()
# Out:
# 6.071161e-12
